# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("salary_train.csv")
df.head()
# Out:
#    ID education_level  years_experience          job_title    industry  \
# 0   1     High School              12.0     Data Scientist   Education
# 1   2             PhD              17.0     Data Scientist          IT
# 2   3             PhD              12.0  Software Engineer   Education
# 3   4       Bachelors               1.0            Analyst  Healthcare
# 4   5     High School               0.0            Analyst          IT
#
#    location company_size  certifications   age  working_hours crucial_code  \
# 0  New York       Medium             1.0  48.0           52.0       XEV156
# 1  New York          NaN             0.0  39.0           34.0          NaN
# 2  New York        Large             4.0   NaN           42.0       FIK684
# 3  New York        Small             2.0  34.0            NaN       DKD155
# 4  New York        Small             1.0  38.0           40.0       ZZH645
#
#         salary
# 0          NaN
# 1          NaN
# 2  95136.09799
# 3  70682.30628
# 4  64887.65469

# %%
df.shape
# Out:
# (11000, 12)

# %%
df = df.drop(["ID", "crucial_code"],axis=1)

# %%
df =df[df.isnull().sum(axis=1) <= 2]

# %%
df.shape
# Out:
# (10902, 10)

# %%
import seaborn as sns
sns.boxplot(df['salary'])  # See if extreme outliers exist
# Out:
# <Axes: ylabel='salary'>

# %%
df = df[df['salary'] < df['salary'].quantile(0.99)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10290 entries, 2 to 10999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   education_level   9780 non-null   object
#  1   years_experience  9797 non-null   float64
#  2   job_title         9800 non-null   object
#  3   industry          9800 non-null   object
#  4   location          10290 non-null  object
#  5   company_size      9804 non-null   object
#  6   certifications    9801 non-null   float64
#  7   age               9795 non-null   float64
#  8   working_hours     9802 non-null   float64
#  9   salary            10290 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 884.3+ KB

# %%
df = df.drop_duplicates(keep="first")
df.shape
# Out:
# (10288, 10)

# %%
df.columns
# Out:
# Index(['education_level', 'years_experience', 'job_title', 'industry',
#        'location', 'company_size', 'certifications', 'age', 'working_hours',
#        'salary'],
#       dtype='object')

# %%
df.sample()
# Out:
#      education_level  years_experience job_title   industry   location  \
# 8421     High School              12.0   Manager  Education  Bangalore
#
#      company_size  certifications   age  working_hours       salary
# 8421       Medium             1.0  26.0           33.0  76012.86501

# %%
df.describe()
# Out:
#        years_experience  certifications          age  working_hours  \
# count       9795.000000     9799.000000  9793.000000    9800.000000
# mean           9.540378        1.979794    40.692433      44.510204
# std            5.755153        1.412047    10.998615       8.635023
# min            0.000000        0.000000    22.000000      30.000000
# 25%            5.000000        1.000000    31.000000      37.000000
# 50%           10.000000        2.000000    41.000000      44.000000
# 75%           15.000000        3.000000    50.000000      52.000000
# max           19.000000        4.000000    59.000000      59.000000
#
#               salary
# count   10288.000000
# mean    85958.867517
# std     14722.383842
# min     41036.552490
# 25%     75387.458060
# 50%     86097.653025
# 75%     96507.903135
# max    122416.732900

# %%
# sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['education_level', 'years_experience', 'job_title', 'industry',
#        'location', 'company_size', 'certifications', 'age', 'working_hours',
#        'salary'],
#       dtype='object')

# %%
df['salary'] = df['salary'].fillna(df['salary'].median())

# %%
df.sample(5)
# Out:
#       education_level  years_experience          job_title industry  \
# 8492        Bachelors               NaN            Analyst      NaN
# 2464      High School               8.0            Analyst  Finance
# 10715     High School               3.0  Software Engineer       IT
# 4217              PhD               6.0  Software Engineer  Finance
# 9608              PhD              11.0            Analyst       IT
#
#             location company_size  certifications   age  working_hours  \
# 8492        New York        Small             2.0  29.0           52.0
# 2464       Bangalore        Large             3.0  54.0           50.0
# 10715      Bangalore        Large             1.0  43.0           34.0
# 4217   San Francisco          NaN             4.0  56.0           36.0
# 9608          London        Large             4.0  40.0           54.0
#
#             salary
# 8492   65805.01822
# 2464   70188.25297
# 10715  45564.53559
# 4217   99172.01383
# 9608   95401.37649

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.tail()
# Out:
#        years_experience  certifications   age  working_hours       salary  \
# 10994               NaN             3.0  45.0           43.0  60689.22500
# 10996               4.0             1.0  30.0           58.0  68231.00794
# 10997              12.0             0.0  31.0           52.0  96753.22060
# 10998               3.0             2.0  50.0           32.0  98773.40580
# 10999               7.0             2.0  28.0           37.0  68906.12689
#
#        education_level_High School  education_level_Masters  \
# 10994                        False                    False
# 10996                        False                    False
# 10997                        False                    False
# 10998                        False                     True
# 10999                        False                    False
#
#        education_level_PhD  job_title_Data Scientist  job_title_Manager  \
# 10994                False                     False              False
# 10996                 True                     False              False
# 10997                False                      True              False
# 10998                False                     False               True
# 10999                False                     False              False
#
#        job_title_Software Engineer  industry_Finance  industry_Healthcare  \
# 10994                         True             False                False
# 10996                        False              True                False
# 10997                        False              True                False
# 10998                        False             False                 True
# 10999                        False             False                False
#
#        industry_IT  location_London  location_New York  \
# 10994         True            False               True
# 10996        False            False              False
# 10997        False            False              False
# 10998        False            False              False
# 10999        False             True              False
#
#        location_San Francisco  company_size_Medium  company_size_Small
# 10994                   False                 True               False
# 10996                   False                False                True
# 10997                    True                 True               False
# 10998                    True                False               False
# 10999                   False                False               False

# %%
X = df.drop("salary",axis=1)
y = df["salary"]

# %%
X.head()
# Out:
#    years_experience  certifications   age  working_hours  \
# 2              12.0             4.0   NaN           42.0
# 3               1.0             2.0  34.0            NaN
# 4               0.0             1.0  38.0           40.0
# 5              17.0             3.0  35.0           37.0
# 6               6.0             2.0  40.0           43.0
#
#    education_level_High School  education_level_Masters  education_level_PhD  \
# 2                        False                    False                 True
# 3                        False                    False                False
# 4                         True                    False                False
# 5                        False                    False                 True
# 6                         True                    False                False
#
#    job_title_Data Scientist  job_title_Manager  job_title_Software Engineer  \
# 2                     False              False                         True
# 3                     False              False                        False
# 4                     False              False                        False
# 5                     False               True                        False
# 6                     False              False                         True
#
#    industry_Finance  industry_Healthcare  industry_IT  location_London  \
# 2             False                False        False            False
# 3             False                 True        False            False
# 4             False                False         True            False
# 5             False                 True        False            False
# 6             False                False         True            False
#
#    location_New York  location_San Francisco  company_size_Medium  \
# 2               True                   False                False
# 3               True                   False                False
# 4               True                   False                False
# 5               True                   False                False
# 6               True                   False                 True
#
#    company_size_Small
# 2               False
# 3                True
# 4                True
# 5               False
# 6               False

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y, test_size=0.33,random_state=1)

# %%
# from sklearn.model_selection import GridSearchCV

# param_grid = {
#     'n_estimators': [100, 200],
#     'max_depth': [10, 20],
#     'min_samples_split': [2, 5],
#     'min_samples_leaf': [1, 2],
# }
# grid = GridSearchCV(RandomForestRegressor(random_state=1), param_grid, cv=5, scoring='r2')
# grid.fit(X_train, y_train)

# %%
from sklearn.metrics import mean_squared_error, median_absolute_error, r2_score
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
xgb = XGBRegressor(random_state=42)
params = {
    'n_estimators': [100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.05, 0.1],
    'subsample': [0.8, 1]
}

grid = GridSearchCV(xgb, params, cv=5, scoring='r2')
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'learning_rate': [0.05, 0.1], 'max_depth': [3, 5, 7],
#                          'n_estimators': [100, 200], 'subsample': [0.8, 1]},
#              scoring='r2')

# %%
# DT = DecisionTreeRegressor()
# RF = RandomForestRegressor()

# %%
grid.score(X_train,y_train)
# Out:
# 0.7273561101847024

# %%
# RF.fit(X_train, y_train)

# %%
# RF.score(X_train,y_train)

# %%
Y_pred = grid.predict(X_test)

# %%
# from sklearn.metrics import mean_squared_error, median_absolute_error, r2_score
# mse = mean_squared_error(y_test,Y_pred)
# mae = median_absolute_error(y_test,Y_pred)
# r2 = r2_score(y_test,Y_pred)
# print("MSE :",{mse}, "MAE :", {mae},"R2 :", {r2})

# %%
# y_pred = DT.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, median_absolute_error, r2_score
mse = mean_squared_error(y_test,Y_pred)
mae = median_absolute_error(y_test,Y_pred)
r2 = r2_score(y_test,Y_pred)
r2 = r2_score(y_test,Y_pred)
print("MSE :",{mse}, "MAE :", {mae})
print(r2)
# Out:
# MSE : {62354419.476018056} MAE : {5230.766892499996}
# 0.7031662663011036

# %%
import joblib
# joblib.dump(RF, "model.pkl")

# %%
import joblib
# joblib.dump(X.columns.tolist(), 'features.pkl')
